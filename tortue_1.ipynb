# %% [markdown]
# Commençons par importer le module turtle.

# %%
from turtle import *

# %% [markdown]
# A) Tester le programme suivant :
# L'instruction done() est obligatoire en fin de programme.

# %%
forward(100)
left(90)
forward(200)
left(90)
color('green')
forward(100)
done()

# %% [markdown]
# B1) Construire la figure suivante :
# ![image.png](attachment:image.png)

# %%
done()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# B2) Modifier le programme précédent pour obtenir cette figure.
# ![image.png](attachment:image.png)

# %% [markdown]
# C1) Tester le programme précédent.

# %%
for i in range(3):
    forward(100)
    left(120)
done()

# %% [markdown]
# C2) Modifier le programme précédent pour obtenir un carré vert.

# %%
for i in range(3):
    forward(100)
    left(120)
done()

# %% [markdown]
# Puis pour obtenir un décagone orange.
# (Si vous ne savez pas ce qu'est un décagone régulier, google est votre ami).

# %%
for i in range(3):
    forward(100)
    left(120)
done()

# %% [markdown]
# D) Construire la ligne en pointillés suivante :
# ![image.png](attachment:image.png)

# %%
done()

# %% [markdown]
# Défi
# ![image.png](attachment:image.png)

# %%
done()
